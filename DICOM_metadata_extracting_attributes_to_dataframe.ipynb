# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunantha17/dicom_metadata_extraction/blob/main/DICOM_metadata_extracting_attributes_to_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DICOM metadata

# %% [markdown]
# This notebook extracts all possible metadata from DICOM files and saves it into a DataFrame (I will also create a .csv file for portability to other notebooks). The process takes a few minutes and is very memory expensive, so better done just once.
#
# In this other notebook I'm using this data to perform an initial research on what does each attribute mean and an EDA. This notebook just dumps the data into CSV.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pydicom
from tqdm import tqdm
import os

# %% [markdown]
# **1. File Listing:**
#
# Find the names for all the files in the training set with .dcm extension.

# %%
dcms = []
for root, dirs, fnames in os.walk('/path/folder/dicom_files'):
    dcms += list(os.path.join(root, f) for f in fnames if f.endswith('.dcm'))
print(f'There are {len(dcms)} CT scans')
# Out:
# There are 550 CT scans

# %% [markdown]
# 2. **Attribute name listing:**
#
# Let's get all the attributes present in any of the DICOM files. The .dir() method comes in handy for this. Note that some files have some attributes and some others do not, so inspecting a single file is not enough. Running this takes some minutes.

# %%
attrs = set()
for fname in tqdm(dcms):
    with pydicom.dcmread(fname) as obj:
        attrs.update(obj.dir())
# Out:
# 100%|██████████| 550/550 [00:00<00:00, 826.73it/s]

# %% [markdown]
# This is a complete list of the DICOM attributes. Drop PixelData so we do not run out of memory (this one contains the actual image).

# %%
dcm_keys = list(attrs)
dcm_keys.remove('PixelData') # The actual array of pixels, this is not metadata
dcm_keys.remove('PatientName') # Anonymous data!
dcm_keys
# Out:
# ['PatientID',
#  'GraphicLayerSequence',
#  'ValueType',
#  'FluoroscopyFlag',
#  'InstanceCreationTime',
#  'InstitutionAddress',
#  'InstanceNumber',
#  'StudyDescription',
#  'Columns',
#  'PresentationLUTShape',
#  'VerifyingObserverSequence',
#  'ContrastBolusStartTime',
#  'ConceptNameCodeSequence',
#  'CompletionFlag',
#  'FilterType',
#  'DerivationDescription',
#  'SamplesPerPixel',
#  'GraphicGroupSequence',
#  'ContinuityOfContent',
#  'ScheduledProcedureStepEndDate',
#  'Modality',
#  'DataCollectionDiameter',
#  'ScanOptions',
#  'ReferencedPerformedProcedureStepSequence',
#  'SliceLocation',
#  'Rows',
#  'ContentTemplateSequence',
#  'Manufacturer',
#  'RequestAttributesSequence',
#  'StudyInstanceUID',
#  'LossyImageCompression',
#  'ImageOrientationPatient',
#  'AcquisitionType',
#  'TableFeedPerRotation',
#  'ConversionType',
#  'SOPClassUID',
#  'RescaleSlope',
#  'DateOfSecondaryCapture',
#  'LossyImageCompressionMethod',
#  'AcquisitionDate',
#  'PatientOrientation',
#  'WindowCenter',
#  'PatientPosition',
#  'PerformedProcedureStepEndTime',
#  'PerformedProcedureStepStartTime',
#  'ContentSequence',
#  'SecondaryCaptureDeviceManufacturer',
#  'PatientBirthDate',
#  'LossyImageCompressionRatio',
#  'DisplayedAreaSelectionSequence',
#  'TotalCollimationWidth',
#  'PixelRepresentation',
#  'ProtocolName',
#  'SecondaryCaptureDeviceManufacturerModelName',
#  'SoftcopyVOILUTSequence',
#  'PixelSpacing',
#  'StudyDate',
#  'TimeOfSecondaryCapture',
#  'OperatorsName',
#  'TablePosition',
#  'RescaleIntercept',
#  'SecondaryCaptureDeviceID',
#  'GraphicAnnotationSequence',
#  'FocalSpots',
#  'TubeAngle',
#  'CTDIvol',
#  'BitsStored',
#  'RevolutionTime',
#  'SingleCollimationWidth',
#  'BodyPartExamined',
#  'ExposureTime',
#  'OriginalAttributesSequence',
#  'SeriesDescription',
#  'StudyID',
#  'PerformedProcedureStepID',
#  'PerformedProcedureStepStartDate',
#  'SliceThickness',
#  'PerformedProcedureStepEndDate',
#  'ContentDate',
#  'ContentLabel',
#  'BitsAllocated',
#  'ReconstructionDiameter',
#  'ReferringPhysicianName',
#  'ReconstructionTargetCenterPatient',
#  'TableHeight',
#  'PresentationCreationDate',
#  'SOPInstanceUID',
#  'ScheduledProcedureStepStartDate',
#  'NameOfPhysiciansReadingStudy',
#  'StationName',
#  'SeriesInstanceUID',
#  'PatientSize',
#  'GeneratorPower',
#  'FrameOfReferenceUID',
#  'SpiralPitchFactor',
#  'InstitutionName',
#  'ContentCreatorName',
#  'SoftwareVersions',
#  'RequestingService',
#  'PositionReferenceIndicator',
#  'PlanarConfiguration',
#  'PresentationCreationTime',
#  'ExposureModulationType',
#  'SeriesTime',
#  'PatientWeight',
#  'XRayTubeCurrent',
#  'ContrastBolusAgent',
#  'PatientSex',
#  'PixelAspectRatio',
#  'AcquisitionTime',
#  'AccessionNumber',
#  'ScheduledProcedureStepStartTime',
#  'WindowCenterWidthExplanation',
#  'AcquisitionNumber',
#  'AdmittingDiagnosesDescription',
#  'CompletionFlagDescription',
#  'InstanceCreationDate',
#  'SeriesNumber',
#  'StudyTime',
#  'SecondaryCaptureDeviceSoftwareVersions',
#  'ContributingEquipmentSequence',
#  'VerificationFlag',
#  'RotationDirection',
#  'HighBit',
#  'ScheduledProcedureStepEndTime',
#  'Exposure',
#  'ContentTime',
#  'EstimatedDoseSaving',
#  'PerformedProcedureCodeSequence',
#  'PhotometricInterpretation',
#  'PatientAge',
#  'KVP',
#  'GantryDetectorTilt',
#  'ContentDescription',
#  'ImagePositionPatient',
#  'SpecificCharacterSet',
#  'WindowWidth',
#  'ConvolutionKernel',
#  'DeviceSerialNumber',
#  'ManufacturerModelName',
#  'SeriesDate',
#  'RequestedProcedureDescription',
#  'ImageComments',
#  'ReferencedSeriesSequence',
#  'InstitutionalDepartmentName',
#  'ImageType']

# %% [markdown]
# 3. **Load the actual values from the files:**
#
# If an attribute is not present, we stick an np.nan. We also perform some casting to standard Python types to make things easier.

# %%
meta = []
typemap = {
    pydicom.uid.UID: str,
    pydicom.multival.MultiValue: list
}
def cast(x):
    return typemap.get(type(x), lambda x: x)(x)

for i, fname in enumerate(tqdm(dcms)):
    with pydicom.dcmread(fname) as obj:
        meta.append([cast(obj.get(key, np.nan)) for key in dcm_keys])

dfmeta = pd.DataFrame(meta, columns=dcm_keys)
dfmeta
# Out:
#   0%|          | 0/550 [00:00<?, ?it/s]/Users/sunanthakannan/anaconda3/lib/python3.11/site-packages/pydicom/valuerep.py:443: UserWarning: The value length (18) exceeds the maximum length of 16 allowed for VR SH.
#   warnings.warn(msg)
# 100%|██████████| 550/550 [00:01<00:00, 545.06it/s]
#         PatientID GraphicLayerSequence ValueType FluoroscopyFlag  \
# 0    OH001Q161421                  NaN       NaN              NO
# 1    OH001Q161421                  NaN       NaN              NO
# 2    OH001Q161421                  NaN       NaN              NO
# 3    OH001Q161421                  NaN       NaN              NO
# 4    OH001Q161421                  NaN       NaN              NO
# ..            ...                  ...       ...             ...
# 545  OH001Q161421                  NaN       NaN              NO
# 546  OH001Q161421                  NaN       NaN              NO
# 547  OH001Q161421                  NaN       NaN              NO
# 548  OH001Q161421                  NaN       NaN              NO
# 549  OH001Q161421                  NaN       NaN              NO
#
#     InstanceCreationTime InstitutionAddress  InstanceNumber  \
# 0                    NaN        TOSHIBA_MEC              74
# 1                    NaN        TOSHIBA_MEC              67
# 2                    NaN        TOSHIBA_MEC              56
# 3                    NaN        TOSHIBA_MEC              18
# 4                    NaN        TOSHIBA_MEC              80
# ..                   ...                ...             ...
# 545                  NaN        TOSHIBA_MEC              71
# 546                  NaN        TOSHIBA_MEC              19
# 547                  NaN        TOSHIBA_MEC               1
# 548                  NaN        TOSHIBA_MEC              17
# 549                  NaN        TOSHIBA_MEC              87
#
#        StudyDescription  Columns PresentationLUTShape  ... WindowWidth  \
# 0    CTA CHEST WO W CON    512.0                  NaN  ...       400.0
# 1    CTA CHEST WO W CON    512.0                  NaN  ...       400.0
# 2    CTA CHEST WO W CON    512.0                  NaN  ...       400.0
# 3    CTA CHEST WO W CON    512.0                  NaN  ...       400.0
# 4    CTA CHEST WO W CON    512.0                  NaN  ...       400.0
# ..                  ...      ...                  ...  ...         ...
# 545  CTA CHEST WO W CON    512.0                  NaN  ...      1600.0
# 546  CTA CHEST WO W CON    512.0                  NaN  ...       400.0
# 547  CTA CHEST WO W CON    512.0                  NaN  ...       400.0
# 548  CTA CHEST WO W CON    512.0                  NaN  ...       400.0
# 549  CTA CHEST WO W CON    512.0                  NaN  ...       400.0
#
#     ConvolutionKernel DeviceSerialNumber ManufacturerModelName SeriesDate  \
# 0                FC07         FLB1662113        Aquilion PRIME   20230105
# 1                FC07         FLB1662113        Aquilion PRIME   20230105
# 2                FC07         FLB1662113        Aquilion PRIME   20230105
# 3                FC07         FLB1662113        Aquilion PRIME   20230105
# 4                FC07         FLB1662113        Aquilion PRIME   20230105
# ..                ...                ...                   ...        ...
# 545              FC50         FLB1662113        Aquilion PRIME   20230105
# 546              FC07         FLB1662113        Aquilion PRIME   20230105
# 547              FC07         FLB1662113        Aquilion PRIME   20230105
# 548              FC07         FLB1662113        Aquilion PRIME   20230105
# 549              FC07         FLB1662113        Aquilion PRIME   20230105
#
#     RequestedProcedureDescription  ImageComments ReferencedSeriesSequence  \
# 0                 CTA CHEST W CON    CTA\Sag-MIP                      NaN
# 1                 CTA CHEST W CON            CTA                      NaN
# 2                 CTA CHEST W CON    CTA\Sag-MIP                      NaN
# 3                 CTA CHEST W CON   CTA\Sagittal                      NaN
# 4                 CTA CHEST W CON            CTA                      NaN
# ..                            ...            ...                      ...
# 545               CTA CHEST W CON            CTA                      NaN
# 546               CTA CHEST W CON   CTA\Sagittal                      NaN
# 547               CTA CHEST W CON    CTA\Cor-MIP                      NaN
# 548               CTA CHEST W CON            CTA                      NaN
# 549               CTA CHEST W CON   CTA\Sagittal                      NaN
#
#     InstitutionalDepartmentName                   ImageType
# 0                 ID_DEPARTMENT     [DERIVED, PRIMARY, MPR]
# 1                 ID_DEPARTMENT  [ORIGINAL, PRIMARY, AXIAL]
# 2                 ID_DEPARTMENT     [DERIVED, PRIMARY, MPR]
# 3                 ID_DEPARTMENT     [DERIVED, PRIMARY, MPR]
# 4                 ID_DEPARTMENT  [ORIGINAL, PRIMARY, AXIAL]
# ..                          ...                         ...
# 545               ID_DEPARTMENT  [ORIGINAL, PRIMARY, AXIAL]
# 546               ID_DEPARTMENT     [DERIVED, PRIMARY, MPR]
# 547               ID_DEPARTMENT     [DERIVED, PRIMARY, MPR]
# 548               ID_DEPARTMENT  [ORIGINAL, PRIMARY, AXIAL]
# 549               ID_DEPARTMENT     [DERIVED, PRIMARY, MPR]
#
# [550 rows x 146 columns]

# %% [markdown]
# 4. **Writing into CSV file**

# %%
dfmeta.to_csv('filename.csv', index=False)
